# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import os


df = pd.read_csv("../dataset/Indian_healthcare.csv")

print("Original Shape:", df.shape)


if "Patient_ID" in df.columns:
    df = df.drop("Patient_ID", axis=1)


if "Visit_Date" in df.columns:
    df["Visit_Date"] = pd.to_datetime(df["Visit_Date"])
    df["Visit_Year"] = df["Visit_Date"].dt.year
    df["Visit_Month"] = df["Visit_Date"].dt.month
    df = df.drop("Visit_Date", axis=1)


text_columns = [
    "Symptoms",
    "Imaging_Findings",
    "Occupation"
]

for column in text_columns:
    if column in df.columns:
        df = df.drop(column, axis=1)


categorical_columns = df.select_dtypes(
    include=["object", "category", "bool"]
).columns

encoder = LabelEncoder()

for column in categorical_columns:
    df[column] = encoder.fit_transform(
        df[column].astype(str)
    )


print("\nProcessed Dataset:")
print(df.head())

print("\nProcessed Shape:")
print(df.shape)

print("\nData Types:")
print(df.dtypes)

print("\nMissing Values:")
print(df.isnull().sum())


os.makedirs("../outputs", exist_ok=True)

df.to_csv(
    "../outputs/processed_healthcare_data.csv",
    index=False
)

print("\nPreprocessing Completed Successfully!")
print("Saved as: ../outputs/processed_healthcare_data.csv")
# Out:
# Original Shape: (100000, 19)
#
# Processed Dataset:
#    Age  Gender  Region  Socioeconomic_Status  Primary_Diagnosis  \
# 0   53       0       0                     1                  3
# 1   36       1       5                     1                  5
# 2   28       1       4                     1                  4
# 3   34       0       2                     1                  1
# 4   48       0       5                     0                  4
#
#    Blood_Glucose_mg_dL  HbA1c_%  Total_Cholesterol_mg_dL  Treatment_Type  \
# 0                100.9      5.9                    233.4               3
# 1                121.3      2.5                    231.1               4
# 2                 74.7      8.6                    260.8               3
# 3                102.7      5.2                    244.8               0
# 4                 61.0      6.0                    280.3               1
#
#    Treatment_Outcome  Imaging_Type  Hospital_Type  Insurance_Covered   BMI  \
# 0                  0             2              1                  0  23.3
# 1                  2             4              2                  1  26.9
# 2                  0             4              2                  1  29.1
# 3                  2             0              1                  0  26.4
# 4                  1             1              1                  1  33.1
#
#    Visit_Year  Visit_Month
# 0        2025            9
# 1        2024           11
# 2        2026            2
# 3        2025           11
# 4        2025            8
#
# Processed Shape:
# (100000, 16)
#
# Data Types:
# Age                          int64
# Gender                       int64
# Region                       int64
# Socioeconomic_Status         int64
# Primary_Diagnosis            int64
# Blood_Glucose_mg_dL        float64
# HbA1c_%                    float64
# Total_Cholesterol_mg_dL    float64
# Treatment_Type               int64
# Treatment_Outcome            int64
# Imaging_Type                 int64
# Hospital_Type                int64
# Insurance_Covered            int64
# BMI                        float64
# Visit_Year                   int32
# Visit_Month                  int32
# dtype: object
#
# Missing Values:
# C:\Users\Boomika.L\AppData\Local\Temp\ipykernel_36928\3685576540.py:33: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = df.select_dtypes(
# Age                        0
# Gender                     0
# Region                     0
# Socioeconomic_Status       0
# Primary_Diagnosis          0
# Blood_Glucose_mg_dL        0
# HbA1c_%                    0
# Total_Cholesterol_mg_dL    0
# Treatment_Type             0
# Treatment_Outcome          0
# Imaging_Type               0
# Hospital_Type              0
# Insurance_Covered          0
# BMI                        0
# Visit_Year                 0
# Visit_Month                0
# dtype: int64
#
# Preprocessing Completed Successfully!
# Saved as: ../outputs/processed_healthcare_data.csv
