# %%
import joblib
import pandas as pd

# %%
model = joblib.load("../models/best_model.pkl")

# %%
new_data = pd.DataFrame({
    "age": [55],
    "sex": [1],
    "bmi": [34.8],
    "children": [2],
    "smoker": [1],
    "region": [1]
})

# %%
prediction = model.predict(new_data)

print(f"Predicted Insurance Charges: ₹{prediction[0]:,.2f}")
# Out:
# Predicted Insurance Charges: ₹45,677.98

# %%
new_data = pd.DataFrame({
    "age": [22],
    "sex": [0],
    "bmi": [22.5],
    "children": [0],
    "smoker": [0],
    "region": [2]
})
