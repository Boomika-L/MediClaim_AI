# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../dataset/insurance.csv")

# %%
plt.figure(figsize=(8,5))
plt.hist(df['age'], bins=20)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['bmi'], bins=20)
plt.title("BMI Distribution")
plt.xlabel("BMI")
plt.ylabel("Count")
plt.show()

# %%
df['sex'].value_counts().plot(kind='bar')
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
df['smoker'].value_counts().plot(kind='bar')
plt.title("Smoker Distribution")
plt.xlabel("Smoker")
plt.ylabel("Count")
plt.show()

# %%
df['region'].value_counts().plot(kind='bar')
plt.title("Region Distribution")
plt.xlabel("Region")
plt.ylabel("Count")
plt.show()

# %%
df.groupby('smoker')['charges'].mean().plot(kind='bar')
plt.title("Average Insurance Charges by Smoking Status")
plt.xlabel("Smoker")
plt.ylabel("Average Charges")
plt.show()

# %%
print(df[['age','bmi','children','charges']].corr())
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %% [markdown]
# 02_Exploratory_Data_Analysis.ipynb
#
# Cell 1 → Import Libraries
# Cell 2 → Load Dataset
# Cell 3 → View Dataset
# Cell 4 → Age Distribution
# Cell 5 → BMI Distribution
# Cell 6 → Gender Distribution
# Cell 7 → Smoker Distribution
# Cell 8 → Region Distribution
# Cell 9 → Charges vs Smoker
# Cell 10 → Charges vs Gender
# Cell 11 → Correlation
# Cell 12 → Observations
